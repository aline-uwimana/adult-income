# %% [markdown]
# # UCI Adult Income Dataset -Exploratory and Descriptive Analysis
# This processing is focused on the data preparation

# %%
import pandas as pd 
import numpy as np 
import os 
import plotly.express as px

# %% [markdown]
# ## Define and Create Paths

# %%
# Get working directory 
current_dir = os.getcwd()

# Go one directory up to the root directory 
project_root_dir = os.path.dirname(current_dir)

data_dir = os.path.join(project_root_dir, 'data')
raw_dir = os.path.join(data_dir,'raw')
processed_dir = os.path.join(data_dir,'processed')

# Define paths to results folder 
results_dir = os.path.join(project_root_dir,'results')

# Define paths to docs folder 
docs_dir = os.path.join(project_root_dir,'docs') 

#Create directories if they do not exist 
os.makedirs(raw_dir,exist_ok= True)
os.makedirs(processed_dir,exist_ok= True)
os.makedirs(results_dir,exist_ok= True)
os.makedirs(data_dir,exist_ok= True)

# %% [markdown]
# ### Read in the data

# %%
adult_data_filename = os.path.join(processed_dir, 'adult_cleaned.csv')
adult_df = pd.read_csv(adult_data_filename)
adult_df.head(10)
# Out:
#    age      workclass  fnlwgt  education_num         marital_status  \
# 0   39     government   77516             13                 single
# 1   50  self-employed   83311             13                married
# 2   38        private  215646              9  divorced or separated
# 3   53        private  234721              7                married
# 4   28        private  338409             13                married
# 5   37        private  284582             14                married
# 6   49        private  160187              5  divorced or separated
# 7   52  self-employed  209642              9                married
# 8   31        private   45781             14                 single
# 9   42        private  159449             13                married
#
#     relationship   race     sex  capital_gain  capital_loss  hours_per_week  \
# 0         single  white    male          2174             0              40
# 1    male spouse  white    male             0             0              13
# 2         single  white    male             0             0              40
# 3    male spouse  black    male             0             0              40
# 4  female spouse  black  female             0             0              40
# 5  female spouse  white  female             0             0              40
# 6         single  black  female             0             0              16
# 7    male spouse  white    male             0             0              45
# 8         single  white  female         14084             0              50
# 9    male spouse  white    male          5178             0              40
#
#   income       education_level occupation_grouped    native_region age_group
# 0  <=50k              tertiary       white collar    north america     36-45
# 1  <=50k              tertiary       white collar    north america     46-60
# 2  <=50k  high school graduate        blue collar    north america     36-45
# 3  <=50k             secondary        blue collar    north america     46-60
# 4  <=50k              tertiary       white collar  central america     26-35
# 5  <=50k              tertiary       white collar    north america     36-45
# 6  <=50k             secondary            service  central america     46-60
# 7   >50k  high school graduate       white collar    north america     46-60
# 8   >50k              tertiary       white collar    north america     26-35
# 9   >50k              tertiary       white collar    north america     36-45

# %% [markdown]
# ## Check the shape of the dataset and datatypes

# %%
adult_df.shape
# Out:
# (32514, 16)

# %%
adult_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32514 entries, 0 to 32513
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 32514 non-null  int64
#  1   workclass           32514 non-null  object
#  2   fnlwgt              32514 non-null  int64
#  3   education_num       32514 non-null  int64
#  4   marital_status      32514 non-null  object
#  5   relationship        32514 non-null  object
#  6   race                32514 non-null  object
#  7   sex                 32514 non-null  object
#  8   capital_gain        32514 non-null  int64
#  9   capital_loss        32514 non-null  int64
#  10  hours_per_week      32514 non-null  int64
#  11  income              32514 non-null  object
#  12  education_level     32514 non-null  object
#  13  occupation_grouped  32514 non-null  object
#  14  native_region       32514 non-null  object
#  15  age_group           32514 non-null  object
# dtypes: int64(6), object(10)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Summary Statistics
# ### Numerical Variables

# %%
adult_df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32514.000000  3.251400e+04   32514.000000  32514.000000  32514.000000
# mean      38.589746  1.897964e+05      10.081626   1079.206619     87.430030
# std       13.639033  1.055780e+05       2.571975   7390.514416    403.237687
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178330e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370615e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32514.000000
# mean        40.440949
# std         12.349994
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Categorical Variables

# %%
adult_df.describe(include='object')
# Out:
#        workclass marital_status relationship   race    sex income  \
# count      32514          32514        32514  32514  32514  32514
# unique         7              4            5      5      2      2
# top      private        married  male spouse  white   male  <=50k
# freq       22650          14984        13178  27772  21758  24678
#
#              education_level occupation_grouped  native_region age_group
# count                  32514              32514          32514     32514
# unique                     7                  5              6         7
# top     high school graduate       white collar  north america     26-35
# freq                   10484              16533          30019      8501

# %%
adult_df['workclass'].value_counts(normalize=True)
# Out:
# workclass
# private          0.696623
# self-employed    0.112444
# government       0.104294
# unknown          0.056468
# federal-gov      0.029526
# voluntary        0.000431
# unemployed       0.000215
# Name: proportion, dtype: float64

# %%
adult_df['relationship'].value_counts(normalize=True)
# Out:
# relationship
# male spouse          0.405302
# single               0.360706
# child                0.155595
# female spouse        0.048225
# extended relative    0.030172
# Name: proportion, dtype: float64

# %%
adult_df['race'].value_counts(normalize=True)
# Out:
# race
# white                        0.854155
# black                        0.096020
# asian or pacific islander    0.031925
# american indian or eskimo    0.009565
# other                        0.008335
# Name: proportion, dtype: float64

# %% [markdown]
# ## Income distribution

# %%
adult_df_income = adult_df.groupby('income').size().reset_index(name='total')
adult_df_income
# Out:
#   income  total
# 0  <=50k  24678
# 1   >50k   7836

# %%
fig = px.pie(adult_df_income, names='income', values='total', title='Overall Income Distribution', color_discrete_sequence=px.colors.sequential.RdBu)

fig.update_layout(template="presentation", paper_bgcolor="rgba(0,0,0,0)", plot_bgcolor="rgba(0,0,0,0)")

fig.show()

fig.write_image(os.path.join(results_dir, 'income_distribution_pie_chart.jpg'))
fig.write_image(os.path.join(results_dir, 'income_distribution_pie_chart.png'))
fig.write_html(os.path.join(results_dir, 'income_distribution_pie_chart.html'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 7
#       3 fig.update_layout(template="presentation", paper_bgcolor="rgba(0,0,0,0)", plot_bgcolor="rgba(0,0,0,0)")
#       5 fig.show()
# ----> 7 fig.write_image(os.path.join(results_dir, 'income_distribution_pie_chart.jpg'))
#       8 fig.write_image(os.path.join(results_dir, 'income_distribution_pie_chart.png'))
#       9 fig.write_html(os.path.join(results_dir, 'income_distribution_pie_chart.html'))
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:3829, in write_image(self, *args, **kwargs)
#    3819 def write_image(self, *args, **kwargs):
#    3820     """
#    3821     Convert a figure to a static image and write it to a file or writeable
#    3822     object
#    3823
#    3824     Parameters
#    3825     ----------
#    3826     file: str or writeable
#    3827         A string representing a local file path or a writeable object
#    3828         (e.g. a pathlib.Path object or an open file descriptor)
# -> 3829
#    3830     format: str or None
#    3831         The desired image format. One of
#    3832           - 'png'
#    3833           - 'jpg' or 'jpeg'
#    3834           - 'webp'
#    3835           - 'svg'
#    3836           - 'pdf'
#    3837           - 'eps' (Kaleido v0.* only) (Requires the poppler library to be installed)
#    3838
#    3839         If not specified and `file` is a string then this will default to the
#    3840         file extension. If not specified and `file` is not a string then this
#    3841         will default to:
#    3842             - `plotly.io.defaults.default_format` or `plotly.io.kaleido.scope.default_format` if engine is "kaleido"
#    3843             - `plotly.io.orca.config.default_format` if engine is "orca"
#    3844
#    3845     width: int or None
#    3846         The width of the exported image in layout pixels. If the `scale`
#    3847         property is 1.0, this will also be the width of the exported image
#    3848         in physical pixels.
#    3849
#    3850         If not specified, will default to:
#    3851             - `plotly.io.defaults.default_width` or `plotly.io.kaleido.scope.default_width` if engine is "kaleido"
#    3852             - `plotly.io.orca.config.default_width` if engine is "orca"
#    3853
#    3854     height: int or None
#    3855         The height of the exported image in layout pixels. If the `scale`
#    3856         property is 1.0, this will also be the height of the exported image
#    3857         in physical pixels.
#    3858
#    3859         If not specified, will default to:
#    3860             - `plotly.io.defaults.default_height` or `plotly.io.kaleido.scope.default_height` if engine is "kaleido"
#    3861             - `plotly.io.orca.config.default_height` if engine is "orca"
#    3862
#    3863     scale: int or float or None
#    3864         The scale factor to use when exporting the figure. A scale factor
#    3865         larger than 1.0 will increase the image resolution with respect
#    3866         to the figure's layout pixel dimensions. Whereas as scale factor of
#    3867         less than 1.0 will decrease the image resolution.
#    3868
#    3869         If not specified, will default to:
#    3870             - `plotly.io.defaults.default_scale` or `plotly.io.kaleido.scope.default_scale` if engine is "kaleido"
#    3871             - `plotly.io.orca.config.default_scale` if engine is "orca"
#    3872
#    3873     validate: bool
#    3874         True if the figure should be validated before being converted to
#    3875         an image, False otherwise.
#    3876
#    3877     engine: str
#    3878         Image export engine to use. This parameter is deprecated and Orca engine support will be
#    3879         dropped in the next major Plotly version. Until then, the following values are supported:
#    3880         - "kaleido": Use Kaleido for image export
#    3881         - "orca": Use Orca for image export
#    3882         - "auto" (default): Use Kaleido if installed, otherwise use Orca
#    3883
#    3884     Returns
#    3885     -------
#    3886     None
#    3887     """
#    3888     import plotly.io as pio
#    3889     from plotly.io.kaleido import (
#    3890         kaleido_available,
#    3891         kaleido_major,
#    (...)
#    3895         ENGINE_PARAM_DEPRECATION_MSG,
#    3896     )
#
# File ~\anaconda3\Lib\site-packages\plotly\io\_kaleido.py:267, in write_image(fig, file, format, scale, width, height, validate, engine)
#     224 def to_image(
#     225     fig: Union[dict, plotly.graph_objects.Figure],
#     226     format: Union[str, None] = None,
#    (...)
#     232     engine: Union[str, None] = None,
#     233 ) -> bytes:
#     234     """
#     235     Convert a figure to a static image bytes string
#     236
#     237     Parameters
#     238     ----------
#     239     fig:
#     240         Figure object or dict representing a figure
#     241
#     242     format: str or None
#     243         The desired image format. One of
#     244             - 'png'
#     245             - 'jpg' or 'jpeg'
#     246             - 'webp'
#     247             - 'svg'
#     248             - 'pdf'
#     249             - 'eps' (Kaleido v0.* only) (Requires the poppler library to be installed and on the PATH)
#     250
#     251         If not specified, will default to:
#     252             - `plotly.io.defaults.default_format` or `plotly.io.kaleido.scope.default_format` if engine is "kaleido"
#     253             - `plotly.io.orca.config.default_format` if engine is "orca"
#     254
#     255     width: int or None
#     256         The width of the exported image in layout pixels. If the `scale`
#     257         property is 1.0, this will also be the width of the exported image
#     258         in physical pixels.
#     259
#     260         If not specified, will default to:
#     261             - `plotly.io.defaults.default_width` or `plotly.io.kaleido.scope.default_width` if engine is "kaleido"
#     262             - `plotly.io.orca.config.default_width` if engine is "orca"
#     263
#     264     height: int or None
#     265         The height of the exported image in layout pixels. If the `scale`
#     266         property is 1.0, this will also be the height of the exported image
# --> 267         in physical pixels.
#     268
#     269         If not specified, will default to:
#     270             - `plotly.io.defaults.default_height` or `plotly.io.kaleido.scope.default_height` if engine is "kaleido"
#     271             - `plotly.io.orca.config.default_height` if engine is "orca"
#     272
#     273     scale: int or float or None
#     274         The scale factor to use when exporting the figure. A scale factor
#     275         larger than 1.0 will increase the image resolution with respect
#     276         to the figure's layout pixel dimensions. Whereas as scale factor of
#     277         less than 1.0 will decrease the image resolution.
#     278
#     279         If not specified, will default to:
#     280             - `plotly.io.defaults.default_scale` or `plotly.io.kaleido.scope.default_scale` if engine is "kaleido"
#     281             - `plotly.io.orca.config.default_scale` if engine is "orca"
#     282
#     283     validate: bool
#     284         True if the figure should be validated before being converted to
#     285         an image, False otherwise.
#     286
#     287     engine: str
#     288         Image export engine to use. This parameter is deprecated and Orca engine support will be
#     289         dropped in the next major Plotly version. Until then, the following values are supported:
#     290           - "kaleido": Use Kaleido for image export
#     291           - "orca": Use Orca for image export
#     292           - "auto" (default): Use Kaleido if installed, otherwise use Orca
#     293
#     294     Returns
#     295     -------
#     296     bytes
#     297         The image data
#     298     """
#     300     # Handle engine
#     301     if engine is not None:
#
# File ~\anaconda3\Lib\site-packages\plotly\io\_kaleido.py:133, in to_image(fig, format, width, height, scale, validate, engine)
#     128     if (
#     129         hasattr(self._scope, name)
#     130         and getattr(self._scope, name) != value
#     131     ):
#     132         setattr(self._scope, name, value)
# --> 133 super().__setattr__(name, value)
#
# ValueError:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido

# %% [markdown]
# ### Income by Age Group

# %%
adult_df_income_age = adult_df.groupby(['age_group','income']).size().reset_index(name='total_by_age')
#sort_values(by='total_by_age', ascending=False)
adult_df_income_age
# Out:
#    age_group income  total_by_age
# 0      18-25  <=50k          5334
# 1      18-25   >50k           114
# 2      26-35  <=50k          6910
# 3      26-35   >50k          1591
# 4      36-45  <=50k          5230
# 5      36-45   >50k          2771
# 6      46-60  <=50k          4479
# 7      46-60   >50k          2809
# 8      61-75  <=50k          1580
# 9      61-75   >50k           511
# 10       76+  <=50k           200
# 11       76+   >50k            40
# 12       <18  <=50k           945

# %%
total_per_group = adult_df_income_age.groupby('age_group')['total_by_age'].transform('sum')
total_per_group
# Out:
# 0     5448
# 1     5448
# 2     8501
# 3     8501
# 4     8001
# 5     8001
# 6     7288
# 7     7288
# 8     2091
# 9     2091
# 10     240
# 11     240
# 12     945
# Name: total_by_age, dtype: int64

# %%
total_per_group = adult_df_income_age.groupby('age_group').size()
total_per_group
# Out:
# age_group
# 18-25    2
# 26-35    2
# 36-45    2
# 46-60    2
# 61-75    2
# 76+      2
# <18      1
# dtype: int64

# %%
total_per_group = adult_df_income_age.groupby('age_group')['total_by_age'].transform('sum')
adult_df_income_age['percentage'] = (adult_df_income_age['total_by_age']/total_per_group) * 100
adult_df_income_age
# Out:
#    age_group income  total_by_age  percentage
# 0      18-25  <=50k          5334   97.907489
# 1      18-25   >50k           114    2.092511
# 2      26-35  <=50k          6910   81.284555
# 3      26-35   >50k          1591   18.715445
# 4      36-45  <=50k          5230   65.366829
# 5      36-45   >50k          2771   34.633171
# 6      46-60  <=50k          4479   61.457190
# 7      46-60   >50k          2809   38.542810
# 8      61-75  <=50k          1580   75.561932
# 9      61-75   >50k           511   24.438068
# 10       76+  <=50k           200   83.333333
# 11       76+   >50k            40   16.666667
# 12       <18  <=50k           945  100.000000

# %%
fig = px.bar(
    adult_df_income_age,
    x = 'age_group',
    y = 'percentage',
    color = 'income',
    title='Incoome Distribution by Age Group(%)',
    barmode='group',
    color_discrete_sequence=px.colors.sequential.RdBu,
    text='percentage'
)
fig.update_traces(texttemplate = '%{text:.2f}%')
fig.show()

# %%
themes = ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "presentation", "xgridoff", "ygridoff", "gridon", "none"]

for theme in themes:
    fig.update_layout(template=theme)

    fig.show()

# %%
adult_df_income_native_region = adult_df.groupby(['native_region', 'income']).size().reset_index(name='total_income_distr')
adult_df_income_native_region
# Out:
#       native_region income  total_income_distr
# 0              asia  <=50k                 465
# 1              asia   >50k                 206
# 2   central america  <=50k                 466
# 3   central america   >50k                  58
# 4            europe  <=50k                 369
# 5            europe   >50k                 152
# 6     north america  <=50k               22769
# 7     north america   >50k                7250
# 8             other  <=50k                 435
# 9             other   >50k                 146
# 10    south america  <=50k                 174
# 11    south america   >50k                  24

# %%
total_per_region = adult_df_income_native_region.groupby('native_region')['total_income_distr'].transform('sum')
adult_df_income_native_region['percentage'] = (adult_df_income_native_region['total_income_distr']/total_per_region) * 100
adult_df_income_native_region
# Out:
#       native_region income  total_income_distr  percentage
# 0              asia  <=50k                 465   69.299553
# 1              asia   >50k                 206   30.700447
# 2   central america  <=50k                 466   88.931298
# 3   central america   >50k                  58   11.068702
# 4            europe  <=50k                 369   70.825336
# 5            europe   >50k                 152   29.174664
# 6     north america  <=50k               22769   75.848629
# 7     north america   >50k                7250   24.151371
# 8             other  <=50k                 435   74.870912
# 9             other   >50k                 146   25.129088
# 10    south america  <=50k                 174   87.878788
# 11    south america   >50k                  24   12.121212

# %%
adult_df_income_native_region = adult_df_income_native_region.drop('percentage of population', axis=1)

# %%
fig = px.bar(
    adult_df_income_native_region,
    x = 'native_region',
    y = 'percentage',
    color = 'income',
    title='Income Distribution across Native Region ',
    barmode='group',
    color_discrete_sequence=px.colors.sequential.RdBu,
    text='percentage'
)
fig.update_traces(texttemplate = '%{text:.2f}%')
fig.show()

# %%
adult_df_income_race = adult_df.groupby(['race', 'income']).size().reset_index(name='total_income_race')
adult_df_income_race
# Out:
#                         race income  total_income_race
# 0  american indian or eskimo  <=50k                275
# 1  american indian or eskimo   >50k                 36
# 2  asian or pacific islander  <=50k                762
# 3  asian or pacific islander   >50k                276
# 4                      black  <=50k               2735
# 5                      black   >50k                387
# 6                      other  <=50k                246
# 7                      other   >50k                 25
# 8                      white  <=50k              20660
# 9                      white   >50k               7112

# %%
total_per_race= adult_df_income_race.groupby('race')['total_income_race'].transform('sum')
adult_df_income_race['percentage'] = (adult_df_income_race['total_income_race']/total_per_race) * 100
adult_df_income_race
# Out:
#                         race income  total_income_race  percentage
# 0  american indian or eskimo  <=50k                275   88.424437
# 1  american indian or eskimo   >50k                 36   11.575563
# 2  asian or pacific islander  <=50k                762   73.410405
# 3  asian or pacific islander   >50k                276   26.589595
# 4                      black  <=50k               2735   87.604100
# 5                      black   >50k                387   12.395900
# 6                      other  <=50k                246   90.774908
# 7                      other   >50k                 25    9.225092
# 8                      white  <=50k              20660   74.391473
# 9                      white   >50k               7112   25.608527

# %%
fig = px.bar(
    adult_df_income_race,
    x = 'race',
    y = 'percentage',
    color = 'income',
    title='Income Distribution Per Race ',
    barmode='group',
    color_discrete_sequence=px.colors.sequential.RdBu,
    text='percentage'
)
fig.update_traces(texttemplate = '%{text:.2f}%')
fig.show()

# %%
adult_df_income_edu_occ = (adult_df.groupby(['education_level', 'occupation_grouped', 'income'])
                          .size().reset_index(name='total').sort_values('total', ascending = False))
adult_df_income_edu_occ
# Out:
#          education_level occupation_grouped income  total
# 10  high school graduate        blue collar  <=50k   3976
# 66              tertiary       white collar  <=50k   3235
# 67              tertiary       white collar   >50k   3141
# 56          some college       white collar  <=50k   3004
# 18  high school graduate       white collar  <=50k   2900
# ..                   ...                ...    ...    ...
# 35               primary            unknown   >50k      4
# 41             secondary           military   >50k      2
# 33               primary            service   >50k      1
# 24             preschool            service   >50k      1
# 22             preschool           military   >50k      1
#
# [68 rows x 4 columns]

# %%
adult_df_income_edu_occ['edu_occ'] = (adult_df_income_edu_occ['education_level'] + " | "
                                     + adult_df_income_edu_occ['occupation_grouped'])
adult_df_income_edu_occ
# Out:
#          education_level occupation_grouped income  total  \
# 10  high school graduate        blue collar  <=50k   3976
# 66              tertiary       white collar  <=50k   3235
# 67              tertiary       white collar   >50k   3141
# 56          some college       white collar  <=50k   3004
# 18  high school graduate       white collar  <=50k   2900
# ..                   ...                ...    ...    ...
# 35               primary            unknown   >50k      4
# 41             secondary           military   >50k      2
# 33               primary            service   >50k      1
# 24             preschool            service   >50k      1
# 22             preschool           military   >50k      1
#
#                                 edu_occ
# 10   high school graduate | blue collar
# 66              tertiary | white collar
# 67              tertiary | white collar
# 56          some college | white collar
# 18  high school graduate | white collar
# ..                                  ...
# 35                    primary | unknown
# 41                 secondary | military
# 33                    primary | service
# 24                  preschool | service
# 22                 preschool | military
#
# [68 rows x 5 columns]

# %%
num = 15
adult_df_combos = adult_df_income_edu_occ.head(num)

fig = px.bar(
    adult_df_combos,
    x='total',
    y='edu_occ',
    color='income',
    orientation='h',
    title=f'Top {num} Education and Occupation Groups Combinations by Income Group',
    height=500,
    width=1100,
    color_discrete_sequence=px.colors.sequential.RdBu,
    text='total'
)

fig.update_layout(
    template="presentation",
    xaxis_title='Number of Individuals',
    yaxis_title='Education | Occupation Group',
    legend_title=dict(text='Income Level'),
    margin=dict(l=450, r=50, t=50, b=50)
)

# Correct method here
fig.update_traces(textposition='inside')

fig.show()

# %% [markdown]
# ### income Distribution
